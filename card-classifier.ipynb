# %%
#import modules
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
import timm

import matplotlib.pyplot as plt # For data viz
import pandas as pd
import numpy as np
import sys
from tqdm.notebook import tqdm

print('System Version:', sys.version)
print('PyTorch version', torch.__version__)
print('Torchvision version', torchvision.__version__)
print('Numpy version', np.__version__)
print('Pandas version', pd.__version__)
# Out:
# System Version: 3.14.2 (tags/v3.14.2:df79316, Dec  5 2025, 17:18:21) [MSC v.1944 64 bit (AMD64)]
# PyTorch version 2.9.1+cu130
# Torchvision version 0.24.1+cu130
# Numpy version 2.3.5
# Pandas version 2.3.3

# %%
# Class for handling the dataset
class PlayingCardDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data = ImageFolder(data_dir, transform=transform)
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return self.data[idx]
    
    @property
    def classes(self):
        return self.data.classes

# %%
# create an instance of the dataset and get the number of samples 
dataset = PlayingCardDataset(data_dir='./dataset')
len(dataset)
# Out:
# 8154

# %%
# test the dataset and print the label and image
image, label = dataset[6769]
print(label)
image
# Out:
# 1
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
#Create a dictionary to identify the meaning of each number in the label
data_dir = './dataset/train'
target_to_class = {v: k for k, v in ImageFolder(data_dir).class_to_idx.items()}
print(target_to_class)
# Out:
# {0: 'ace of clubs', 1: 'ace of diamonds', 2: 'ace of hearts', 3: 'ace of spades', 4: 'eight of clubs', 5: 'eight of diamonds', 6: 'eight of hearts', 7: 'eight of spades', 8: 'five of clubs', 9: 'five of diamonds', 10: 'five of hearts', 11: 'five of spades', 12: 'four of clubs', 13: 'four of diamonds', 14: 'four of hearts', 15: 'four of spades', 16: 'jack of clubs', 17: 'jack of diamonds', 18: 'jack of hearts', 19: 'jack of spades', 20: 'joker', 21: 'king of clubs', 22: 'king of diamonds', 23: 'king of hearts', 24: 'king of spades', 25: 'nine of clubs', 26: 'nine of diamonds', 27: 'nine of hearts', 28: 'nine of spades', 29: 'queen of clubs', 30: 'queen of diamonds', 31: 'queen of hearts', 32: 'queen of spades', 33: 'seven of clubs', 34: 'seven of diamonds', 35: 'seven of hearts', 36: 'seven of spades', 37: 'six of clubs', 38: 'six of diamonds', 39: 'six of hearts', 40: 'six of spades', 41: 'ten of clubs', 42: 'ten of diamonds', 43: 'ten of hearts', 44: 'ten of spades', 45: 'three of c
# ...

# %%
# Resize images to a consistent size and transform data into a tensor
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

data_dir = './dataset/train'
dataset = PlayingCardDataset(data_dir, transform)

# %%
image, label = dataset[1200]
image.shape
# Out:
# torch.Size([3, 128, 128])

# %%
for image, label in dataset:
    break

# %%
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
for images, labels in dataloader:
    break

# %%
images.shape, labels.shape
# Out:
# (torch.Size([32, 3, 128, 128]), torch.Size([32]))

# %%
labels
# Out:
# tensor([22, 31, 40, 17, 40, 29, 18,  8, 15, 52, 28, 32, 52, 16, 49, 24, 31, 30,
#         35, 31, 10, 49, 50, 25, 37, 36, 23,  3, 35, 40, 42, 49])

# %%
class SimpleCardClassifier(nn.Module):
    def __init__(self, num_classes=53):
        super(SimpleCardClassifier, self).__init__()
        self.base_model = timm.create_model('efficientnet_b0', pretrained=True)
        self.features = nn.Sequential(*list(self.base_model.children())[:-1])
        enet_out_size = 1280
        
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(enet_out_size, num_classes)
        )
    
    def forward(self, x):
        # Connect these parts and return the output
        x = self.features(x)
        output = self.classifier(x)
        return output

# %%
model =  SimpleCardClassifier(num_classes=53)
print(str(model)[:500])
# Out:
# SimpleCardClassifier(
#   (base_model): EfficientNet(
#     (conv_stem): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNormAct2d(
#       32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#       (drop): Identity()
#       (act): SiLU(inplace=True)
#     )
#     (blocks): Sequential(
#       (0): Sequential(
#         (0): DepthwiseSeparableConv(
#           (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=Fa

# %%
example_output = model(images)
example_output.shape # [batch_size, num_classes]
# Out:
# torch.Size([32, 53])

# %%
# Loss function
criterion = nn.CrossEntropyLoss()
# Optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

criterion(example_output, labels)
print(example_output.shape, labels.shape)
# Out:
# torch.Size([32, 53]) torch.Size([32])

# %%
train_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomRotation(3),            # Very slight rotation only
    transforms.ColorJitter(brightness=0.05, contrast=0.05),  # Minimal color variation
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# Validation/Test transform 
val_test_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

train_folder = './dataset/train'
valid_folder = './dataset/valid'
test_folder = './dataset/test'

train_dataset = PlayingCardDataset(train_folder, transform=train_transform)
val_dataset = PlayingCardDataset(valid_folder, transform=val_test_transform)
test_dataset = PlayingCardDataset(test_folder, transform=val_test_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print(" Data augmentation enabled for training!")
print(f"Training samples: {len(train_dataset)} (with augmentation)")
print(f"Validation samples: {len(val_dataset)} (no augmentation)")
print(f"Test samples: {len(test_dataset)} (no augmentation)")
# Out:
#  Data augmentation enabled for training!
# Training samples: 7624 (with augmentation)
# Validation samples: 265 (no augmentation)
# Test samples: 265 (no augmentation)

# %%
import matplotlib.pyplot as plt

# Get one image from training set
image, label = train_dataset[0]

# Show multiple augmented versions of the same image
fig, axes = plt.subplots(2, 4, figsize=(12, 6))
axes = axes.flatten()

for i in range(8):
    # Get the same image index but augmentation is random each time
    aug_image, _ = train_dataset[0]
    
    # Denormalize for viewing (reverse the normalization)
    mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    aug_image = aug_image * std + mean
    aug_image = torch.clamp(aug_image, 0, 1)
    
    # Convert to numpy and transpose for matplotlib
    aug_image = aug_image.permute(1, 2, 0).numpy()
    
    axes[i].imshow(aug_image)
    axes[i].axis('off')
    axes[i].set_title(f'Augmentation {i+1}')

plt.suptitle('8 Random Augmentations of the Same Card')
plt.tight_layout()
plt.show()

# %%
# Class to save the best model during training
class ModelCheckpoint:
    def __init__(self, filepath='best_card_classifier.pth', verbose=True):
        self.filepath = filepath
        self.verbose = verbose
        self.best_loss = float('inf')
        
    def save_model(self, model, val_loss, epoch):
        if val_loss < self.best_loss:
            if self.verbose:
                print(f'\n💾 Validation loss improved ({self.best_loss:.4f} → {val_loss:.4f}). Saving model...')
            self.best_loss = val_loss
        
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'val_loss': val_loss,
            }, self.filepath)

# %%
#Stop training when validation loss stops improving
class EarlyStopping:  
    def __init__(self, patience=5, min_delta=0.001, verbose=True):
        self.patience = patience 
        self.min_delta = min_delta  #
        self.verbose = verbose
        self.counter = 0
        self.best_loss = float('inf')
        self.early_stop = False
        
    def should_stop(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            # Improvement detected
            self.best_loss = val_loss
            self.counter = 0
            if self.verbose:
                print(f'✓ Validation loss improved to {val_loss:.4f}')
        else:
            # No improvement
            self.counter += 1
            if self.verbose:
                print(f'⏳ No improvement for {self.counter}/{self.patience} epochs')
            
            if self.counter >= self.patience:
                self.early_stop = True
                if self.verbose:
                    print(f'⏹️ Early stopping! No improvement for {self.patience} epochs.')
                return True
        
        return False
        
# Make use of a GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda:0

# %%
# Checkpoint before training starts
checkpoint = ModelCheckpoint(filepath='best_card_classifier.pth')

# Create early stopping object
early_stopping = EarlyStopping(patience=5) 

num_epochs = 100
train_losses, val_losses = [], []

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model = SimpleCardClassifier(num_classes=53)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
checkpoint = ModelCheckpoint(filepath='best_card_classifier.pth')

for epoch in range(num_epochs):
    # Set model to train
    model.train()
    running_loss = 0.0
    for images, labels in tqdm(train_loader, desc='Training loop'):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * labels.size(0)
    train_loss = running_loss / len(train_loader.dataset)
    train_losses.append(train_loss)
    
    # Validation phase
    model.eval()
    running_loss = 0.0
    with torch.no_grad():
        for images, labels in tqdm(val_loader, desc='Validation loop'):
            # Move inputs and labels to the device
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * labels.size(0)
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    print(f"Epoch {epoch+1}/{num_epochs} - Train loss: {train_loss:.4f}, Validation loss: {val_loss:.4f}")
        # saves the best model
    checkpoint.save_model(model, val_loss, epoch+1)
    
    # Check if should stop early
    if early_stopping.should_stop(val_loss):
        print(f"\n Stopping training at epoch {epoch+1}")
        break
# Out:
# Using device: cuda:0
# ...
# Validation loop:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 1/100 - Train loss: 1.5964, Validation loss: 0.4771
#
# 💾 Validation loss improved (inf → 0.4771). Saving model...
# ✓ Validation loss improved to 0.4771
# ...
# Validation loop:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 2/100 - Train loss: 0.6496, Validation loss: 0.2429
#
# 💾 Validation loss improved (0.4771 → 0.2429). Saving model...
# ✓ Validation loss improved to 0.2429
# ...
# Validation loop:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 3/100 - Train loss: 0.4350, Validation loss: 0.3497
# ⏳ No improvement for 1/5 epochs
# ...
# Validation loop:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 4/100 - Train loss: 0.3264, Validation loss: 0.2011
#
# 💾 Validation loss improved (0.2429 → 0.2011). Saving model...
# ✓ Validation loss improved to 0.2011
# ...
# Validation loop:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 5/100 - Train loss: 0.2381, Validation loss: 0.1492
#
# ...

# %%
# Load the best saved model
checkpoint_data = torch.load('best_card_classifier.pth')
model.load_state_dict(checkpoint_data['model_state_dict'])
print(f" Loaded best model from epoch {checkpoint_data['epoch']}")
print(f"   Best validation loss: {checkpoint_data['val_loss']:.4f}")
# Out:
#  Loaded best model from epoch 12
#    Best validation loss: 0.0773

# %%
#visualize loss over multiple epochs
plt.plot(train_losses, label='Training loss')
plt.plot(val_losses, label='Validation loss')
plt.legend()
plt.title("Loss over epochs")
plt.show()

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# Load and preprocess the image
def preprocess_image(image_path, transform):
    image = Image.open(image_path).convert("RGB")
    return image, transform(image).unsqueeze(0)

# Predict using the model
def predict(model, image_tensor, device):
    model.eval()
    with torch.no_grad():
        image_tensor = image_tensor.to(device)
        outputs = model(image_tensor)
        probabilities = torch.nn.functional.softmax(outputs, dim=1)
    return probabilities.cpu().numpy().flatten()

# Visualization
def visualize_predictions(original_image, probabilities, class_names):
    fig, axarr = plt.subplots(1, 2, figsize=(14, 7))
    
    # Display image
    axarr[0].imshow(original_image)
    axarr[0].axis("off")
    
    # Display predictions
    axarr[1].barh(class_names, probabilities)
    axarr[1].set_xlabel("Probability")
    axarr[1].set_title("Class Predictions")
    axarr[1].set_xlim(0, 1)

    plt.tight_layout()
    plt.show()

# Example usage
test_image = "./dataset/test/queen of spades/3.jpg"
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

original_image, image_tensor = preprocess_image(test_image, transform)
probabilities = predict(model, image_tensor, device)

# Assuming dataset.classes gives the class names
class_names = dataset.classes 
visualize_predictions(original_image, probabilities, class_names)

# %%
# example usage
from glob import glob
test_images = glob('./dataset/test/*/*')
test_examples = np.random.choice(test_images, 6)

for example in test_examples:
    original_image, image_tensor = preprocess_image(example, transform)
    probabilities = predict(model, image_tensor, device)

    # Assuming dataset.classes gives the class names
    class_names = dataset.classes 
    visualize_predictions(original_image, probabilities, class_names)

# %%
# Calculate the Accuracy of the Model using test data
from sklearn.metrics import accuracy_score

model.eval()
true_labels = []
predicted_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        
        outputs = model(images)
        _, predictions = torch.max(outputs, 1)  # Get the class index with the highest probability
        true_labels.extend(labels.cpu().numpy())
        predicted_labels.extend(predictions.cpu().numpy())

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Test Accuracy: 97.36%

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Create a confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Identify the top 10 classes based on prediction frequency
top_n_classes = np.argsort(np.bincount(predicted_labels))[::-1][:15]

# Extract the relevant rows and columns from the confusion matrix
conf_matrix_top_n = conf_matrix[top_n_classes][:, top_n_classes]

# Get the class names for the top 10 classes
class_names_top_n = [dataset.classes[i] for i in top_n_classes]

# Display the confusion matrix for the top 10 classes with rotated labels
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_top_n, display_labels=class_names_top_n)
disp.plot(cmap='Blues', values_format='d', xticks_rotation=90)
plt.show()
